# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\admin\anaconda3\lib\site-packages (0.0)
# ...

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %%
df = pd.read_csv("lyrics.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    Unnamed: 0      genre            artist                song  \
# 0           0  Christian    Glory Revealed       By His Wounds
# 1           1  Christian    Caedmon's Call      God of Wonders
# 2           2  Christian           MercyMe  I Can Only Imagine
# 3           3  Christian       Aaron Shust    My Savior My God
# 4           4  Christian  Michael W. Smith             Breathe
#
#                                               lyrics  wordcount  \
# 0  glory revealed by his wounds he was pierced fo...        205
# 1  lord of heaven and earth lord of all creation ...        217
# 2  i can only imagine what it will be like when i...        275
# 3  i am not skilled to understand what god has wi...        371
# 4  this is the air i breathe this is the air i br...        198
#
#    nostopwordcount  positivewordcount  negativewordcount  neutralwordcount
# 0               79                  7                 16                56
# ...

# %%
#only taking the lyrics from the dataframe
lyrics_df = df['lyrics']

# %%
lyrics_df.head()
# Out:
# 0    glory revealed by his wounds he was pierced fo...
# 1    lord of heaven and earth lord of all creation ...
# 2    i can only imagine what it will be like when i...
# 3    i am not skilled to understand what god has wi...
# 4    this is the air i breathe this is the air i br...
# Name: lyrics, dtype: object

# %%
from Models import worddata
for line in lyrics_df:
    print (worddata.word_calcs(line).nostopwordlist())
# Out:
# ['glory', 'revealed', 'wounds', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'healed', 'sacrifice', 'life', 'gave', 'healed', 'paid', 'price', 'grace', 'saved', 'saved', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'healed', 'sacrifice', 'life', 'gave', 'healed', 'paid', 'price', 'grace', 'saved', 'saved', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'wounds', 'wounds', 'wash', 'away', 'sin', 'nothing', 'blood', 'jesus']
# ...

# %%
## pulling only the genre and the lyrics 
lyrics_test_df = df[['genre','lyrics']]
lyrics_test_df.head()
# Out:
#        genre                                             lyrics
# 0  Christian  glory revealed by his wounds he was pierced fo...
# 1  Christian  lord of heaven and earth lord of all creation ...
# 2  Christian  i can only imagine what it will be like when i...
# 3  Christian  i am not skilled to understand what god has wi...
# 4  Christian  this is the air i breathe this is the air i br...

# %%
# Pivoting the table so that genre becomes the row names and lyrics are the columns for it's genre

lyrics_test_df_pivot = lyrics_test_df.pivot(columns='genre', values='lyrics')
lyrics_test_df_pivot.head()
# Out:
# genre                                          Christian Country Hip Hop/Rap  \
# 0      glory revealed by his wounds he was pierced fo...     NaN         NaN
# 1      lord of heaven and earth lord of all creation ...     NaN         NaN
# 2      i can only imagine what it will be like when i...     NaN         NaN
# 3      i am not skilled to understand what god has wi...     NaN         NaN
# 4      this is the air i breathe this is the air i br...     NaN         NaN
#
# genre Rhythm and Blues Rock
# 0                  NaN  NaN
# 1                  NaN  NaN
# 2                  NaN  NaN
# 3                  NaN  NaN
# 4                  NaN  NaN

# %%
lyrics_test_df_christian = lyrics_test_df_pivot[['Christian']]
lyrics_test_df_christian.head()

# with pd.option_context('display.max_rows', 999):
#     print (lyrics_test_df_christian)
# Out:
# genre                                          Christian
# 0      glory revealed by his wounds he was pierced fo...
# 1      lord of heaven and earth lord of all creation ...
# 2      i can only imagine what it will be like when i...
# 3      i am not skilled to understand what god has wi...
# 4      this is the air i breathe this is the air i br...

# %%
from Models import worddata
for words in lyrics_test_df_christian:
    print (worddata.word_calcs(line).nostopwordlist())
# Out:
# ['cynthia', 'get', 'dance', 'music', 'get', 'dance', 'music', 'dance', 'music', 'dance', 'music', 'dance', 'music', 'dance', 'music', 'hey', 'greg', 'need', 'drummer', 'people', 'need', 'beat', 'yeah', 'im', 'gon', 'na', 'add', 'little', 'guitar', 'make', 'easy', 'move', 'feet', 'im', 'gon', 'na', 'add', 'bottom', 'dancers', 'wont', 'hide', 'might', 'like', 'hear', 'organ', 'said', '``', 'ride', 'sally', 'ride', "''", 'cynthia', 'get', 'could', 'hear', 'horns', 'blowin', 'cynthia', 'throne', 'yeah', 'listen', 'cynthia', 'jerry', 'got', 'message', 'theyre', 'sayin', '``', 'squares', 'go', 'home', "''", 'listen', 'voices', 'dance', 'music', 'dance', 'music', 'dance', 'music']

# %%
lyrics_test_df_country = lyrics_test_df_pivot[['Country']]
# lyrics_test_df_country.head()

with pd.option_context('display.max_rows', 999):
    print (lyrics_test_df_country)
# Out:
# genre                                            Country
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# ...

# %%
lyrics_test_df_rap = lyrics_test_df_pivot[['Hip Hop/Rap']]
# lyrics_test_df_rap.head()

with pd.option_context('display.max_rows', 999):
    print (lyrics_test_df_rap)
# Out:
# genre                                        Hip Hop/Rap
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# ...

# %%
lyrics_test_df_randb = lyrics_test_df_pivot[['Rhythm and Blues']]
# lyrics_test_df_randb.head()

with pd.option_context('display.max_rows', 999):
    print (lyrics_test_df_randb)
# Out:
# genre                                   Rhythm and Blues
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# ...

# %%
lyrics_test_df_rock = lyrics_test_df_pivot[['Rock']]
# print(lyrics_test_df_rock)


with pd.option_context('display.max_rows', 999):
    print (lyrics_test_df_rock)
# Out:
# genre                                               Rock
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# ...
